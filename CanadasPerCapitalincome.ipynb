# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
import pandas
df = pd.read_csv("canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
#Plot a Scatter plot
# %matplotlib inline
plt.scatter(df['year'],df['per capita income (US$)'],color='Red',marker='+')
plt.ylabel('per capita income (US$)')
plt.xlabel('Year')
plt.show()

# %%
#create linear regreeeion model
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\PRANAV METE\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
reg.predict([[2000]])
# Out:
# C:\Users\PRANAV METE\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([24719.39258996])

# %%
# %matplotlib inline
plt.scatter(df['year'],df['per capita income (US$)'],color='Red',marker='+')
plt.plot(df['year'],reg.predict(df[['year']]),color='blue')
plt.show()
